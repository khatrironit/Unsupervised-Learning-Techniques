# %% [markdown]
# # K-Means ++
#     -K-means is quite sensitive to init,if the random init is not good it is not able to produce desired number of clusters.
#     -To overcome this problem, K-means++ is used which chooses initial centres such that they are close to the final ones.
#     -This method is default for Sklearn.

# %%
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs

# %%
X,Y = make_blobs(n_samples = 250,n_features = 2, centers = 5,random_state = 3)

# %%
from sklearn.cluster import KMeans

# %%
kmeans = KMeans(n_clusters = 5)

# %%
kmeans.fit(X,Y)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=5, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)

# %%
centers = kmeans.cluster_centers_

# %%
plt.scatter(X[:,0],X[:,1])
plt.scatter(centers[:,0],centers[:,1],color = "orange",marker = "*")
plt.show()

# %%
pred = kmeans.labels_

# %%
plt.scatter(X[:,0],X[:,1],c=pred)
plt.scatter(centers[:,0],centers[:,1],color = "orange",marker = "*")
plt.show()
